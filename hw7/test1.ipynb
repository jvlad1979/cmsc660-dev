# %% [markdown]
# CG
# Input: $x_0$, $r_0 = Ax_0-b$, $p_0 = -r_0$
#
# For k = 0,1,2
#     $\alpha_k = -\frac{r_k^Tp_k}{p_k^TAp_k}$
#     $x_{k+1} = x_k +\alpha_k p_k$
#     $r_{k+1} = r_k +\alpha_k A p_k$
#     $\beta_{k+1} = \frac{r_{k+1}Ap_k}{p_kAp_k}$
#     $p_{k+1}= -r_{k+1} + \beta_{k+1}p_{k}$

# %%
import numpy as np 

N = 69

x0 = np.zeros(N)
b  = np.random.rand(N)

A = np.random.rand(N,N)
A = A.T@A

def conj_grad(A,b,x0):
    r0 = A@x0 -b
    p0 = -r0 
    r = r0 
    p = p0
    x=x0
    eps = 1e-8
    while np.linalg.norm(r)>eps:
        alpha = -(r.T@p)/(p.T@A@p)
        x =x+ alpha*p
        r = r+ alpha*A@p 
        beta = (r.T@A@p)/(p.T@A@p)
        p = -r + beta*p
    return x

x = conj_grad(A,b,x0)

# %%
x
# Out:
# array([-1100.32246932, -1059.87522603,   301.1695332 ,  -747.81339446,
#         -345.203686  ,   131.80769317,   433.1803895 ,  -411.43877612,
#           91.00624985,  -549.76106583,   492.94123245,  -405.1108207 ,
#          459.64159162,  1378.19200711,  -601.15352915,   945.32134436,
#          143.55810973,   667.15878258,  -556.90406376,  1318.5781653 ,
#          783.37863486,  -662.12172399,  -703.27871334,  -282.80949091,
#          249.52122657,   -43.15230279,   802.64885235, -1056.07686153,
#         -264.96031558,  -348.01537419,  -249.60065485,   919.63177179,
#         -214.75221148,   864.56285613,   340.42152141,  -640.19339078,
#          140.37330158,   940.85182707,   176.18021195,   457.63927722,
#         -360.75659247,    21.70045367,  -677.66094452,   137.9119687 ,
#         -388.57199294,  -311.15789847,  -171.16454558,   786.33960553,
#           -1.83790384,  -434.8780081 ,  -256.99222511,   660.52101539,
#         -552.12214203,   -23.50624418,   761.50267659,  -235.80758086,
#         -469.94000666,   117.74429237,  -809.73158127,   299.7778869 ,
#          388.48908389,   429.467065  ,  -943.28230709,   413.0172209 ,
#         -962.27685962,   266.91763233,    18.45068983,    20.59446573,
#          379.45038579])

# %%
np.linalg.solve(A,b)
# Out:
# array([-1100.32246952, -1059.87522622,   301.16953326,  -747.8133946 ,
#         -345.20368607,   131.80769319,   433.18038956,  -411.43877621,
#           91.00624987,  -549.76106591,   492.94123254,  -405.11082077,
#          459.64159171,  1378.19200737,  -601.15352927,   945.32134453,
#          143.55810977,   667.15878269,  -556.90406385,  1318.57816555,
#          783.37863502,  -662.1217241 ,  -703.27871346,  -282.80949098,
#          249.52122662,   -43.15230281,   802.6488525 , -1056.07686172,
#         -264.96031563,  -348.01537426,  -249.60065489,   919.63177197,
#         -214.75221152,   864.56285631,   340.42152146,  -640.19339088,
#          140.37330162,   940.85182725,   176.18021198,   457.6392773 ,
#         -360.75659253,    21.70045368,  -677.66094465,   137.91196874,
#         -388.57199303,  -311.15789853,  -171.16454563,   786.33960566,
#           -1.83790382,  -434.87800818,  -256.99222516,   660.52101552,
#         -552.12214214,   -23.50624417,   761.50267672,  -235.80758091,
#         -469.94000675,   117.74429238,  -809.73158142,   299.77788697,
#          388.48908396,   429.46706507,  -943.28230729,   413.01722098,
#         -962.27685981,   266.91763238,    18.45068983,    20.59446575,
#          379.45038587])
